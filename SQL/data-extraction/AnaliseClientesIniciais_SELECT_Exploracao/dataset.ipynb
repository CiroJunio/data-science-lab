# %%
import pandas as pd
import io

data = """id_cliente,nome,email,cidade,data_cadastro
101,Ana Silva,ana.silva@email.com,São Paulo,2025-08-15
102,Bruno Costa,bruno.c@email.com,Rio de Janeiro,2025-08-16
103,Carla Dias,carla.dias@email.com,Belo Horizonte,2025-08-17
104,Daniel Alves,dani.alves@email.com,São Paulo,2025-08-18
105,Eduarda Lima,edu.lima@email.com,Salvador,2025-08-19
106,Fábio Melo,fabio.melo@email.com,São Paulo,2025-08-20
107,Gisele Faria,gisele@email.com,Curitiba,2025-08-21
108,Heitor Barros,h.barros@email.com,Rio de Janeiro,2025-08-22
"""

df_clientes = pd.read_csv(io.StringIO(data))

# Para simular o ambiente SQL, imagine que 'df_clientes' 
# é uma tabela chamada 'clientes' em um banco de dados.

print(df_clientes.head())
# Out:
#    id_cliente          nome                 email          cidade  \
# 0         101     Ana Silva   ana.silva@email.com       São Paulo
# 1         102   Bruno Costa     bruno.c@email.com  Rio de Janeiro
# 2         103    Carla Dias  carla.dias@email.com  Belo Horizonte
# 3         104  Daniel Alves  dani.alves@email.com       São Paulo
# 4         105  Eduarda Lima    edu.lima@email.com        Salvador
#
#   data_cadastro
# 0    2025-08-15
# 1    2025-08-16
# 2    2025-08-17
# 3    2025-08-18
# 4    2025-08-19
